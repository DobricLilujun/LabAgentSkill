# %%
import anyio
from claude_agent_sdk import query

async def main():
    async for message in query(prompt="What is 2 + 2?"):
        print(message)

anyio.run(main)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 8
#       5     async for message in query(prompt="What is 2 + 2?"):
#       6         print(message)
# ----> 8 anyio.run(main)
#
# File ~/projects_lujun/LabAgentSkill/.venv/lib/python3.12/site-packages/anyio/_core/_eventloop.py:62, in run(func, backend, backend_options, *args)
#      44 """
#      45 Run the given coroutine function in an asynchronous event loop.
#      46
#    (...)     59
#      60 """
#      61 if asynclib_name := current_async_library():
# ---> 62     raise RuntimeError(f"Already running {asynclib_name} in this thread")
#      64 try:
#      65     async_backend = get_async_backend(backend)
#
# RuntimeError: Already running asyncio in this thread
